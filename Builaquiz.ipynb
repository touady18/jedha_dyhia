# %%
def quiz():
    try:
        winner = False
        print("Welcome to our quiz!!!")
        print("Let's start :) ")
        print("------------")
        answer_1 = 2
        answer_2 = 1976
        answer_3 = "elon musk"
        cpt = 2
        
        #Question 1 :
        print("Question 1 ")
        print(" 1 + 1 = ? ")
        user_answer = int(input("Enter your answer"))
        while cpt >= 0 :
            if user_answer == answer_1:
                print("Good job! That is the right answer")
                winner = True
                break
            elif cpt == 0:
                return print("Oh no, you lost the quiz...")
                break
            elif cpt > 0:
                print("Sorry, you have {} chances left".format(cpt))
                user_answer = int(input("Enter your answer"))
                cpt-=1
        



        #Question 2 :
        print("Question 2 ")
        cpt = 2
        print("Year you born?")
        user_answer = int(input("Enter your answer"))
        while cpt >= 0 :
            if user_answer == answer_2:
                print("Good job! That is the right answer")
                winner = True
                break
            elif cpt == 0:
                return print("Oh no, you lost the quiz...")
                break
            elif cpt > 0:
                print("Sorry, you have {} chances left".format(cpt))
                user_answer = int(input("Enter your answer"))
                cpt-=1


        #Question 3 :
        print("Question 3")
        cpt = 2
        print(" Who is the COE of Tesla? ")
        user_answer = input("Enter your answer")
        while cpt >= 0 :
            if user_answer.lower() == answer_3:
                print("Good job! That is the right answer")
                winner = True
                break
            elif cpt == 0:
                return print("Oh no, you lost the quiz...")
                break
            elif cpt > 0:
                print("Sorry, you have {} chances left".format(cpt))
                user_answer = int(input("Enter your answer"))
                cpt-=1
        if winner == True:
           return print("Well done! You are the quiz winner!")
        else: 
            return print("Oh no, you lost the quiz")
    except ValueError as e :
        print(e)
        
    
quiz()
